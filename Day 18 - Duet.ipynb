# %% [markdown]
# # --- Day 18: Duet ---
#
# http://adventofcode.com/2017/day/18
#
# You discover a tablet containing some strange assembly code labeled simply "Duet". Rather than bother the sound card with it, you decide to run the code yourself. Unfortunately, you don't see any documentation, so you're left to figure out what the instructions mean on your own.
#
# It seems like the assembly is meant to operate on a set of registers that are each named with a single letter and that can each hold a single integer. You suppose each register should start with a value of 0.
#
# There aren't that many instructions, so it shouldn't be hard to figure out what they do. Here's what you determine:
#
# - snd X plays a sound with a frequency equal to the value of X.
# - set X Y sets register X to the value of Y.
# - add X Y increases register X by the value of Y.
# - mul X Y sets register X to the result of multiplying the value contained in register X by the value of Y.
# - mod X Y sets register X to the remainder of dividing the value contained in register X by the value of Y (that is, it sets X to the result of X modulo Y).
# - rcv X recovers the frequency of the last sound played, but only when the value of X is not zero. (If it is zero, the command does nothing.)
# - jgz X Y jumps with an offset of the value of Y, but only if the value of X is greater than zero. (An offset of 2 skips the next instruction, an offset of -1 jumps to the previous instruction, and so on.)
#
# Many of the instructions can take either a register (a single letter) or a number. The value of a register is the integer it contains; the value of a number is that number.
#
# After each jump instruction, the program continues with the instruction to which the jump jumped. After any other instruction, the program continues with the next instruction. Continuing (or jumping) off either end of the program terminates it.
#
# For example:
#
# ```
# set a 1
# add a 2
# mul a a
# mod a 5
# snd a
# set a 0
# rcv a
# jgz a -1
# set a 1
# jgz a -2
# ```
#
# - The first four instructions set a to 1, add 2 to it, square it, and then set it to itself modulo 5, resulting in a value of 4.
# - Then, a sound with frequency 4 (the value of a) is played.
# - After that, a is set to 0, causing the subsequent rcv and jgz instructions to both be skipped (rcv because a is 0, and jgz because a is not greater than 0).
# - Finally, a is set to 1, causing the next jgz instruction to activate, jumping back two instructions to another jump, which jumps again to the rcv, which ultimately triggers the recover operation.
#
# At the time the recover operation is executed, the frequency of the last sound played is 4.
#
# **What is the value of the recovered frequency** (the value of the most recently played sound) the first time a rcv instruction is executed with a non-zero value?

# %% [markdown]
# ## Part one solution:
#
# This is similar to an earlier solution, the key thing is knowing the collections and using defaultdic, and parsing the incoming instructions:

# %%
# the puzzle input
with open('puzzle_inputs/day18_input.txt') as f:
    data = f.read().strip().split("\n")
puzzle_input = [line for line in data]
puzzle_input[:10]

# %%
from collections import defaultdict

def part_one(instructions, verbose=False):
    """goes through instructions and perfoms them as per part one"""
    
    registers = defaultdict(int)
    sounds = []
    i = 0
    total_instructions = len(instructions)
    
    while i >=0 and i < total_instructions:
        
        # first, parse instruction
        f = instructions[i].split()
        if verbose: print(i, f)
        func = f[0]
        
        try:
            x = int(f[1])
        except:
            x = f"'{f[1]}'"

        if len(f) == 3:
            try:
                y = int(f[2])
            except:
                y = f"'{f[2]}'"
        
        if func == "rcv":
            if verbose: print(registers)
            print("part one answer is:", sounds[-1])
            break
        
        # now to run the func code
        
        if func == "snd":
            sounds.append(registers[x])
        elif func == "set":
            y = registers[y] if type(y) is str else y
            registers[x] = y
        elif func == "add":
            y = registers[y] if type(y) is str else y
            registers[x] += y
        elif func == "mul":
            y = registers[y] if type(y) is str else y
            registers[x] = registers[x] * y
        elif func == "mod":
            y = registers[y] if type(y) is str else y
            registers[x] = registers[x] % y
        elif func == "rcv":
            x = registers[x] if type(x) is str else x
            if x != 0:
                sounds.append(sounds[-1])
        elif func == "jgz":
            x = registers[x] if type(x) is str else x
            if x > 0:
                i += registers[y] if type(y) is str else y
                if verbose: print(f"jumping to {i}")
                # now to skip the i += step below
                continue
                
        i += 1

part_one(puzzle_input, verbose=True)
# Out:
# 0 ['set', 'i', '31']
# 1 ['set', 'a', '1']
# 2 ['mul', 'p', '17']
# 3 ['jgz', 'p', 'p']
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# jumping to 4
# 4 ['mul', 'a', '2']
# 5 ['add', 'i', '-1']
# 6 ['jgz', 'i', '-2']
# 7 ['add', 'a', '-1']
# 8 ['set', 'i', '127']
# 9 ['set', 'p', '735']
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# jumping to 10
# 10 ['mul', 'p', '8505']
# 11 ['mod', 'p', 'a']
# 12 ['mul', 'p', '129749']
# 13 ['add', 'p', '12345']
# 14 ['mod', 'p', 'a']
# 15 ['set', 'b', 'p']
# 16 ['mod', 'b', '10000']
# 17 ['snd', 'b']
# 18 ['add', 'i', '-1']
# 19 ['jgz', 'i', '-9']
# 20 ['jgz', 'a', '3']
# jumping to 23
# 23 ['set', 'f', '0']
# 24 ['set', 'i', '126']
# 25 ['rcv', 'a']
# defaultdict(<class 'int'>, {"'i'": 126, "'a'": 2147483647, "'p'": 1666308600, "'b'": 8600, "'f'": 0})
# part one answer is: 8600

# %% [markdown]
# `8600` was the right answer for my puzzle input! yay!

# %% [markdown]
# # --- Part Two ---
#
# As you congratulate yourself for a job well done, you notice that the documentation has been on the back of the tablet this entire time. While you actually got most of the instructions correct, there are a few key differences. This assembly code isn't about sound at all - it's meant to be run twice at the same time.
#
# Each running copy of the program has its own set of registers and follows the code independently - in fact, the programs don't even necessarily run at the same speed. To coordinate, they use the send (snd) and receive (rcv) instructions:
#
# - `snd X` sends the value of X to the other program. These values wait in a queue until that program is ready to receive them. Each program has its own message queue, so a program can never receive a message it sent.
# - `rcv X` receives the next value and stores it in register X. If no values are in the queue, the program waits for a value to be sent to it. Programs do not continue to the next instruction until they have received a value. Values are received in the order they are sent.
#
# Each program also has its own program ID (one 0 and the other 1); the register p should begin with this value.
#
# For example:
#
# ```
# snd 1
# snd 2
# snd p
# rcv a
# rcv b
# rcv c
# rcv d```
#
# Both programs begin by sending three values to the other. Program 0 sends 1, 2, 0; program 1 sends 1, 2, 1. Then, each program receives a value (both 1) and stores it in a, receives another value (both 2) and stores it in b, and then each receives the program ID of the other program (program 0 receives 1; program 1 receives 0) and stores it in c. Each program now sees a different value in its own copy of register c.
#
# Finally, both programs try to rcv a fourth time, but no data is waiting for either of them, and they reach a deadlock. When this happens, both programs terminate.
#
# It should be noted that it would be equally valid for the programs to run at different speeds; for example, program 0 might have sent all three values and then stopped at the first rcv before program 1 executed even its first instruction.
#
# Once both of your programs have terminated (regardless of what caused them to do so), **how many times did program 1 send a value?**

# %% [markdown]
# This seems like a good reason use multi-threading/processing, probably using Process, Queue, Pipe from mp, but since I'm using jupyter notebook running in termux on a chromebook, multiprocessing doesn't work:
#
# > This platform lacks a functioning sem_open implementation, therefore, the required synchronization primitives needed will not function, see issue 3770.
#
# so trying threading:

# %%
from threading import Thread, Lock
from queue import Queue
from collections import defaultdict

# the puzzle input
with open('puzzle_inputs/day18_input.txt') as f:
    data = f.read().strip().split("\n")
puzzle_input = [line for line in data]

def do_ins_threaded(instructions, progam_id, inqueue, outqueue, verbose=False):
    """goes through instructions and perfoms them as per part one"""
    
    registers = defaultdict(int)
    registers["p"] = progam_id
    
    total_instructions = len(instructions)
    sent_msgs = 0
    rcv_msgs = 0
    i = 0
    
    while i >=0 and i < total_instructions:
        # first, parse instruction
        f = instructions[i].split()
        #if verbose: print(progam_id, i, f)
        func = f[0]
        
        try:
            x = int(f[1])
        except:
            x = f"'{f[1]}'"

        if len(f) == 3:
            try:
                y = int(f[2])
            except:
                y = f"'{f[2]}'"
        
        # now to run the func code
        if func == "rcv":
            try:
                registers["x"] = inqueue.get(timeout=1)
            except:
                print(f"no more messages left for Program {progam_id}")
                break
            rcv_msgs += 1
            if verbose: print(f"Progam {progam_id} received msg {rcv_msgs}")
        elif func == "snd":
            #with lock:
            outqueue.put(registers[x])
            sent_msgs += 1
            if verbose: print(f"Program {progam_id} sent message {sent_msgs}")
        elif func == "set":
            y = registers[y] if type(y) is str else y
            registers[x] = y
        elif func == "add":
            y = registers[y] if type(y) is str else y
            registers[x] += y
        elif func == "mul":
            y = registers[y] if type(y) is str else y
            registers[x] = registers[x] * y
        elif func == "mod":
            y = registers[y] if type(y) is str else y
            registers[x] = registers[x] % y
        elif func == "jgz":
            x = registers[x] if type(x) is str else x
            if x > 0:
                i += registers[y] if type(y) is str else y
                continue # skip the i += step below
        else:
            print(f"found unknown command {func}, halting...")
            break
                
        i += 1
        
    print(f"----{progam_id} ends here----")
    print(f"P {progam_id} sent {sent_msgs} messages, received {rcv_msgs} msgs")
    print("-------")
    
    return True

# %%
test_input = """snd 1
snd 2
snd p
rcv a
rcv b
rcv c
rcv d""".strip().split("\n")
print(test_input)

q1 = Queue()
q2 = Queue()

t1 = Thread(target=do_ins_threaded, args=(test_input, 0, q1, q2, True,))
t2 = Thread(target=do_ins_threaded, args=(test_input, 1, q2, q1, True,))

t1.start() 
t2.start()
# Out:
# ['snd 1', 'snd 2', 'snd p', 'rcv a', 'rcv b', 'rcv c', 'rcv d']
# Program 0 sent message 1
# Program 0 sent message 2
# Program 0 sent message 3
# Program 1 sent message 1Progam 0 received msg 1
#
# Program 1 sent message 2
# Program 1 sent message 3
# Progam 1 received msg 1
# Progam 1 received msg 2
# Progam 1 received msg 3
# Progam 0 received msg 2
# Progam 0 received msg 3
# no more messages left for Program 1no more messages left for Program 0
# ----0 ends here----
# P 0 sent 3 messages, received 3 msgs
# -------
#
# ----1 ends here----
# P 1 sent 3 messages, received 3 msgs
# -------

# %%
q1 = Queue()
q2 = Queue()

t1 = Thread(target=do_ins_threaded, args=(puzzle_input, 0, q1, q2, False,))
t2 = Thread(target=do_ins_threaded, args=(puzzle_input, 1, q2, q1, True,))

t1.start() 
t2.start()
# Out:
# Program 1 sent message 1
# Program 1 sent message 2
# Program 1 sent message 3
# Program 1 sent message 4
# Program 1 sent message 5
# Program 1 sent message 6
# Program 1 sent message 7
# Program 1 sent message 8
# Program 1 sent message 9
# Program 1 sent message 10
# Program 1 sent message 11
# Program 1 sent message 12
# Program 1 sent message 13
# Program 1 sent message 14
# Program 1 sent message 15
# Program 1 sent message 16
# Program 1 sent message 17
# Program 1 sent message 18
# Program 1 sent message 19
# Program 1 sent message 20
# Program 1 sent message 21
# Program 1 sent message 22
# Program 1 sent message 23
# Program 1 sent message 24
# Program 1 sent message 25
# Program 1 sent message 26
# Program 1 sent message 27
# Program 1 sent message 28
# Program 1 sent message 29
# Program 1 sent message 30
# Program 1 sent message 31
# Program 1 sent message 32
# Program 1 sent message 33
# Program 1 sent message 34
# Program 1 sent message 35
# Program 1 sent message 36
# Program 1 sent message 37
# Program 1 sent message 38
# Program 1 sent message 39
# Program 1 sent message 40
# Program 1 sent message 41
# Program 1 sent message 42
# Program 1 sent message 43
# Program 1 sent message 44
# Program 1 sent message 45
# Program 1 sent message 46
# Program 1 sent message 47
# Program 1 sent message 48
# Program 1 sent message 49
# Program 1 sent message 50
# Program 1 sent message 51
# Program 1 sent message 52
# Program 1 sent message 53
# Program 1 sent message 54
# Program 1 sent message 55
# Program 1 sent message 56
# Program 1 sent message 57
# Program 1 sent message 58
# Program 1 sent message 59
# Program 1 sent message 60
# Program 1 sent message 61
# Program 1 sent message 62
# Program 1 sent message 63
# Program 1 sent message 64
# Program 1 sent message 65
# Program 1 sent message 66
# Program 1 sent message 67
# Program 1 sent message 68
# Program 1 sent message 69
# Program 1 sent message 70
# Program 1 sent message 71
# Program 1 sent message 72
# Program 1 sent message 73
# Program 1 sent message 74
# Program 1 sent message 75
# Program 1 sent message 76
# Program 1 sent message 77
# Program 1 sent message 78
# Program 1 sent message 79
# Program 1 sent message 80
# Program 1 sent message 81
# Program 1 sent message 82
# Program 1 sent message 83
# Program 1 sent message 84
# Program 1 sent message 85
# Program 1 sent message 86
# Program 1 sent message 87
# Program 1 sent message 88
# Program 1 sent message 89
# Program 1 sent message 90
# Program 1 sent message 91
# Program 1 sent message 92
# Program 1 sent message 93
# Program 1 sent message 94
# Program 1 sent message 95
# Program 1 sent message 96
# Program 1 sent message 97
# Program 1 sent message 98
# Program 1 sent message 99
# Program 1 sent message 100
# Program 1 sent message 101
# Program 1 sent message 102
# Program 1 sent message 103
# Program 1 sent message 104
# Program 1 sent message 105
# Program 1 sent message 106
# Program 1 sent message 107
# Program 1 sent message 108
# Program 1 sent message 109
# Program 1 sent message 110
# Program 1 sent message 111
# Program 1 sent message 112
# Program 1 sent message 113
# Program 1 sent message 114
# Program 1 sent message 115
# Program 1 sent message 116
# Program 1 sent message 117
# Program 1 sent message 118
# Program 1 sent message 119
# Program 1 sent message 120
# Program 1 sent message 121
# Program 1 sent message 122
# Program 1 sent message 123
# Program 1 sent message 124
# Program 1 sent message 125
# Program 1 sent message 126
# Program 1 sent message 127
# Progam 1 received msg 1
# Progam 1 received msg 2
# Program 1 sent message 128
# Progam 1 received msg 3
# Program 1 sent message 129
# Progam 1 received msg 4
# Program 1 sent message 130
# Progam 1 received msg 5
# Program 1 sent message 131
# Progam 1 received msg 6
# Program 1 sent message 132
# Progam 1 received msg 7
# Program 1 sent message 133
# Progam 1 received msg 8
# Program 1 sent message 134
# Progam 1 received msg 9
# Program 1 sent message 135
# Progam 1 received msg 10
# Program 1 sent message 136
# Progam 1 received msg 11
# Program 1 sent message 137
# Progam 1 received msg 12
# Program 1 sent message 138
# Progam 1 received msg 13
# Program 1 sent message 139
# Progam 1 received msg 14
# Program 1 sent message 140
# Progam 1 received msg 15
# Program 1 sent message 141
# Progam 1 received msg 16
# Program 1 sent message 142
# Progam 1 received msg 17
# Program 1 sent message 143
# Progam 1 received msg 18
# Program 1 sent message 144
# Progam 1 received msg 19
# Program 1 sent message 145
# Progam 1 received msg 20
# Program 1 sent message 146
# Progam 1 received msg 21
# Program 1 sent message 147
# Progam 1 received msg 22
# Program 1 sent message 148
# Progam 1 received msg 23
# Program 1 sent message 149
# Progam 1 received msg 24
# Program 1 sent message 150
# Progam 1 received msg 25
# Program 1 sent message 151
# Progam 1 received msg 26
# Program 1 sent message 152
# Progam 1 received msg 27
# Program 1 sent message 153
# Progam 1 received msg 28
# Program 1 sent message 154
# Progam 1 received msg 29
# Program 1 sent message 155
# Progam 1 received msg 30
# Program 1 sent message 156
# Progam 1 received msg 31
# Program 1 sent message 157
# Progam 1 received msg 32
# Program 1 sent message 158
# Progam 1 received msg 33
# Program 1 sent message 159
# Progam 1 received msg 34
# Program 1 sent message 160
# Progam 1 received msg 35
# Program 1 sent message 161
# Progam 1 received msg 36
# Program 1 sent message 162
# Progam 1 received msg 37
# Program 1 sent message 163
# Progam 1 received msg 38
# Program 1 sent message 164
# Progam 1 received msg 39
# Program 1 sent message 165
# Progam 1 received msg 40
# Program 1 sent message 166
# Progam 1 received msg 41
# Program 1 sent message 167
# Progam 1 received msg 42
# Program 1 sent message 168
# Progam 1 received msg 43
# Program 1 sent message 169
# Progam 1 received msg 44
# Program 1 sent message 170
# Progam 1 received msg 45
# Program 1 sent message 171
# Progam 1 received msg 46
# Program 1 sent message 172
# Progam 1 received msg 47
# Program 1 sent message 173
# Progam 1 received msg 48
# Program 1 sent message 174
# Progam 1 received msg 49
# Program 1 sent message 175
# Progam 1 received msg 50
# Program 1 sent message 176
# Progam 1 received msg 51
# Program 1 sent message 177
# Progam 1 received msg 52
# Program 1 sent message 178
# Progam 1 received msg 53
# Program 1 sent message 179
# Progam 1 received msg 54
# Program 1 sent message 180
# Progam 1 received msg 55
# Program 1 sent message 181
# Progam 1 received msg 56
# Program 1 sent message 182
# Progam 1 received msg 57
# Program 1 sent message 183
# Progam 1 received msg 58
# Program 1 sent message 184
# Progam 1 received msg 59
# Program 1 sent message 185
# Progam 1 received msg 60
# Program 1 sent message 186
# Progam 1 received msg 61
# Program 1 sent message 187
# Progam 1 received msg 62
# Program 1 sent message 188
# Progam 1 received msg 63
# Program 1 sent message 189
# Progam 1 received msg 64
# Program 1 sent message 190
# Progam 1 received msg 65
# Program 1 sent message 191
# Progam 1 received msg 66
# Program 1 sent message 192
# Progam 1 received msg 67
# Program 1 sent message 193
# Progam 1 received msg 68
# Program 1 sent message 194
# Progam 1 received msg 69
# Program 1 sent message 195
# Progam 1 received msg 70
# Program 1 sent message 196
# Progam 1 received msg 71
# Program 1 sent message 197
# Progam 1 received msg 72
# Program 1 sent message 198
# Progam 1 received msg 73
# Program 1 sent message 199
# Progam 1 received msg 74
# Program 1 sent message 200
# Progam 1 received msg 75
# Program 1 sent message 201
# Progam 1 received msg 76
# Program 1 sent message 202
# Progam 1 received msg 77
# Program 1 sent message 203
# Progam 1 received msg 78
# Program 1 sent message 204
# Progam 1 received msg 79
# Program 1 sent message 205
# Progam 1 received msg 80
# Program 1 sent message 206
# Progam 1 received msg 81
# Program 1 sent message 207
# Progam 1 received msg 82
# Program 1 sent message 208
# Progam 1 received msg 83
# Program 1 sent message 209
# Progam 1 received msg 84
# Program 1 sent message 210
# Progam 1 received msg 85
# Program 1 sent message 211
# Progam 1 received msg 86
# Program 1 sent message 212
# Progam 1 received msg 87
# Program 1 sent message 213
# Progam 1 received msg 88
# Program 1 sent message 214
# Progam 1 received msg 89
# Program 1 sent message 215
# Progam 1 received msg 90
# Program 1 sent message 216
# Progam 1 received msg 91
# Program 1 sent message 217
# Progam 1 received msg 92
# Program 1 sent message 218
# Progam 1 received msg 93
# Program 1 sent message 219
# Progam 1 received msg 94
# Program 1 sent message 220
# Progam 1 received msg 95
# Program 1 sent message 221
# Progam 1 received msg 96
# Program 1 sent message 222
# Progam 1 received msg 97
# Program 1 sent message 223
# Progam 1 received msg 98
# Program 1 sent message 224
# Progam 1 received msg 99
# Program 1 sent message 225
# Progam 1 received msg 100
# Program 1 sent message 226
# Progam 1 received msg 101
# Program 1 sent message 227
# Progam 1 received msg 102
# Program 1 sent message 228
# Progam 1 received msg 103
# Program 1 sent message 229
# Progam 1 received msg 104
# Program 1 sent message 230
# Progam 1 received msg 105
# Program 1 sent message 231
# Progam 1 received msg 106
# Program 1 sent message 232
# Progam 1 received msg 107
# Program 1 sent message 233
# Progam 1 received msg 108
# Program 1 sent message 234
# Progam 1 received msg 109
# Program 1 sent message 235
# Progam 1 received msg 110
# Program 1 sent message 236
# Progam 1 received msg 111
# Program 1 sent message 237
# Progam 1 received msg 112
# Program 1 sent message 238
# Progam 1 received msg 113
# Program 1 sent message 239
# Progam 1 received msg 114
# Program 1 sent message 240
# Progam 1 received msg 115
# Program 1 sent message 241
# Progam 1 received msg 116
# Program 1 sent message 242
# Progam 1 received msg 117
# Program 1 sent message 243
# Progam 1 received msg 118
# Program 1 sent message 244
# Progam 1 received msg 119
# Program 1 sent message 245
# Progam 1 received msg 120
# Program 1 sent message 246
# Progam 1 received msg 121
# Program 1 sent message 247
# Progam 1 received msg 122
# Program 1 sent message 248
# Progam 1 received msg 123
# Program 1 sent message 249
# Progam 1 received msg 124
# Program 1 sent message 250
# Progam 1 received msg 125
# Program 1 sent message 251
# Progam 1 received msg 126
# Program 1 sent message 252
# Progam 1 received msg 127
# Program 1 sent message 253
# Program 1 sent message 254
# Progam 1 received msg 128
# Progam 1 received msg 129
# Progam 1 received msg 130
# Progam 1 received msg 131
# Progam 1 received msg 132
# Progam 1 received msg 133
# Progam 1 received msg 134
# Progam 1 received msg 135
# Progam 1 received msg 136
# Progam 1 received msg 137
# Progam 1 received msg 138
# Progam 1 received msg 139
# Progam 1 received msg 140
# Progam 1 received msg 141
# Progam 1 received msg 142
# Progam 1 received msg 143
# Progam 1 received msg 144
# Progam 1 received msg 145
# Progam 1 received msg 146
# Progam 1 received msg 147
# Progam 1 received msg 148
# Progam 1 received msg 149
# Progam 1 received msg 150
# Progam 1 received msg 151
# Progam 1 received msg 152
# Progam 1 received msg 153
# Progam 1 received msg 154
# Progam 1 received msg 155
# Progam 1 received msg 156
# Progam 1 received msg 157
# Progam 1 received msg 158
# Progam 1 received msg 159
# Progam 1 received msg 160
# Progam 1 received msg 161
# Progam 1 received msg 162
# Progam 1 received msg 163
# Progam 1 received msg 164
# Progam 1 received msg 165
# Progam 1 received msg 166
# Progam 1 received msg 167
# Progam 1 received msg 168
# Progam 1 received msg 169
# Progam 1 received msg 170
# Progam 1 received msg 171
# Progam 1 received msg 172
# Progam 1 received msg 173
# Progam 1 received msg 174
# Progam 1 received msg 175
# Progam 1 received msg 176
# Progam 1 received msg 177
# Progam 1 received msg 178
# Progam 1 received msg 179
# Progam 1 received msg 180
# Progam 1 received msg 181
# Progam 1 received msg 182
# Progam 1 received msg 183
# Progam 1 received msg 184
# Progam 1 received msg 185
# Progam 1 received msg 186
# Progam 1 received msg 187
# Progam 1 received msg 188
# Progam 1 received msg 189
# Progam 1 received msg 190
# Progam 1 received msg 191
# Progam 1 received msg 192
# Progam 1 received msg 193
# Progam 1 received msg 194
# Progam 1 received msg 195
# Progam 1 received msg 196
# Progam 1 received msg 197
# Progam 1 received msg 198
# Progam 1 received msg 199
# Progam 1 received msg 200
# Progam 1 received msg 201
# Progam 1 received msg 202
# Progam 1 received msg 203
# Progam 1 received msg 204
# Progam 1 received msg 205
# Progam 1 received msg 206
# Progam 1 received msg 207
# Progam 1 received msg 208
# Progam 1 received msg 209
# Progam 1 received msg 210
# Progam 1 received msg 211
# Progam 1 received msg 212
# Progam 1 received msg 213
# Progam 1 received msg 214
# Progam 1 received msg 215
# Progam 1 received msg 216
# Progam 1 received msg 217
# Progam 1 received msg 218
# Progam 1 received msg 219
# Progam 1 received msg 220
# Progam 1 received msg 221
# Progam 1 received msg 222
# Progam 1 received msg 223
# Progam 1 received msg 224
# Progam 1 received msg 225
# Progam 1 received msg 226
# Progam 1 received msg 227
# Progam 1 received msg 228
# Progam 1 received msg 229
# Progam 1 received msg 230
# Progam 1 received msg 231
# Progam 1 received msg 232
# Progam 1 received msg 233
# Progam 1 received msg 234
# Progam 1 received msg 235
# Progam 1 received msg 236
# Progam 1 received msg 237
# Progam 1 received msg 238
# Progam 1 received msg 239
# Progam 1 received msg 240
# Progam 1 received msg 241
# Progam 1 received msg 242
# Progam 1 received msg 243
# Progam 1 received msg 244
# Progam 1 received msg 245
# Progam 1 received msg 246
# Progam 1 received msg 247
# Progam 1 received msg 248
# Progam 1 received msg 249
# Progam 1 received msg 250
# Progam 1 received msg 251
# Progam 1 received msg 252
# Progam 1 received msg 253
# Progam 1 received msg 254
# no more messages left for Program 0
# ----0 ends here----
# P 0 sent 254 messages, received 254 msgs
# -------
# no more messages left for Program 1
# ----1 ends here----
# P 1 sent 254 messages, received 254 msgs
# -------

# %%
t1.is_alive(), t2.is_alive()
# Out:
# (False, False)
